# %% [markdown]
# # Import libraries

# %%
import pandas as pd
#from iEEG_modules.explore_viz import *

# %load_ext autoreload
# %autoreload 2

import os
from os import sys
from datetime import datetime, timedelta
import pytz
import re

import mne
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['agg.path.chunksize'] = 10000

pd.set_option('display.max_rows', 100)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# *Script goals*: given an EDF file, output in plots with raw channel signal. One figure per region (e.g. all channels in ROFC will show in the same figure, etc.) Figures are named `viz_[patient ID]_[EDF number]_[region].jpg`.

# %% [markdown]
# # User-specified Inputs

# %%
patient_ID       = 'PR05' # or 'PR03', 'PR05'
edf_dir          = f'/data_store0/presidio/nihon_kohden/{patient_ID}/{patient_ID}/' # folder of raw EDFs
OUT_FN           = '/home/dastudillo/BIDS/metaEDF.csv'

# %%
#read one edf
raw = mne.io.read_raw_edf(os.path.join(edf_dir, 'PR05_0001.edf'))
# Out:
# Extracting EDF parameters from /data_store0/presidio/nihon_kohden/PR05/PR05/PR05_0001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
def get_edf_list(edf_dir):
    edf_list = sorted(filter(lambda x: True if 'edf' in x else False, os.listdir(edf_dir)))
    
    return edf_list

def edf_reader(edf_dir, edf_fn):

    raw = mne.io.read_raw_edf(os.path.join(edf_dir, edf_fn))
        
    edf_len = timedelta(seconds=len(raw)/raw.info['sfreq']) # seconds
    edf_start = raw.info['meas_date']
    edf_end = edf_start + edf_len

    att_dic = {
        'edf_fn': edf_fn,
        'edf_path': os.path.join(edf_dir, edf_fn),
        'edf_start': edf_start.replace(tzinfo=None), 
        'edf_end': edf_end.replace(tzinfo=None),
        'edf_timezone': 'US/Pacific',
        'edf_duration': edf_len,
        'edf_nsample': len(raw),
        'edf_sfreq': raw.info['sfreq'],
        'edf_lowpass': raw.info['lowpass'],
        'edf_highpass': raw.info['highpass'],
        'edf_nchan': raw.info['nchan'],
        'edf_channame': raw.info['ch_names'],
        'edf_axis': list('chan','sample'),
    }
    
    data_dic, time = raw[:,:]
        
    return att_dic, data_dic

# %%
fn_list = get_edf_list(edf_dir)

# %%
edf_reader(edf_dir,fn_list[20])
# Out:
# Extracting EDF parameters from /data_store0/presidio/nihon_kohden/PR05/PR05/PR05_0021.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# ({'edf_fn': 'PR05_0021.edf',
#   'edf_path': '/data_store0/presidio/nihon_kohden/PR05/PR05/PR05_0021.edf',
#   'edf_start': datetime.datetime(2023, 6, 14, 12, 1, 40),
#   'edf_end': datetime.datetime(2023, 6, 14, 12, 6, 40),
#   'edf_timezone': 'US/Pacific',
#   'edf_duration': datetime.timedelta(0, 300),
#   'edf_nsample': 600000,
#   'edf_sfreq': 2000.0,
#   'edf_lowpass': 1000.0,
#   'edf_highpass': 0.0,
#   'edf_nchan': 190,
#   'edf_chname': ['POL DC09-Ref',
#    'POL DC10-Ref',
#    'POL DC11-Ref',
#    'POL R OFC1-Ref',
#    'POL R OFC2-Ref',
#    'POL R OFC3-Ref',
#    'POL R OFC4-Ref',
#    'POL R OFC5-Ref',
#    'POL R OFC6-Ref',
#    'POL R OFC7-Ref',
#    'POL R OFC8-Ref',
#    'POL R OFC9-Ref',
#    'POL R OFC10-Ref',
#    'POL R OFC11-Ref',
#    'POL R OFC12-Ref',
#    'POL R OFC13-Ref',
#    'POL R OFC14-Ref',
#    'POL R OFC15-Ref',
#    'POL R OFC16-Ref',
#    'POL R SGC1-Ref',
#    'POL R SGC2-Ref',
#    'POL R SGC3-Ref',
#    'POL R SGC4-Ref',
#    'POL R SGC5-Ref',
#    'POL R SGC6-Ref',
#    'POL R SGC7-Ref',
#    'POL R SGC8-Ref',
#    'POL R SGC9-Ref',
#    'POL R SGC10-Ref',
#    'POL R SGC11-Ref',
#    'POL R SGC12-Ref',
#    'POL R SGC13-Ref',
#    'POL R SGC14-Ref',
#    'POL R SGC15-Ref',
#    'POL R SGC16-Ref',
#    'POL R H1-Ref',
#    'POL R H2-Ref',
#    'POL R H3-Ref',
#    'POL R H4-Ref',
#    'POL R H5-Ref',
#    'POL R H6-Ref',
#    'POL R H7-Ref',
#    'POL R H8-Ref',
#    'POL R H9-Ref',
#    'POL R H10-Ref',
#    'POL R H11-Ref',
#    'POL R H12-Ref',
#    'POL R H13-Ref',
#    'POL R H14-Ref',
#    'POL R H15-Ref',
#    'POL R H16-Ref',
#    'POL R A1-Ref',
#    'POL R A2-Ref',
#    'POL R A3-Ref',
#    'POL R A4-Ref',
#    'POL R A5-Ref',
#    'POL R A6-Ref',
#    'POL R A7-Ref',
#    'POL R A8-Ref',
#    'POL R A9-Ref',
#    'POL R A10-Ref',
#    'POL R A11-Ref',
#    'POL R A12-Ref',
#    'POL R A13-Ref',
#    'POL R A14-Ref',
#    'POL R A15-Ref',
#    'POL R A16-Ref',
#    'POL L OFC1-Ref',
#    'POL L OFC2-Ref',
#    'POL L OFC3-Ref',
#    'POL L OFC4-Ref',
#    'POL L OFC5-Ref',
#    'POL L OFC6-Ref',
#    'POL L OFC7-Ref',
#    'POL L OFC8-Ref',
#    'POL L OFC9-Ref',
#    'POL L OFC10-Ref',
#    'POL L OFC11-Ref',
#    'POL L OFC12-Ref',
#    'POL L OFC13-Ref',
#    'POL L OFC14-Ref',
#    'POL L OFC15-Ref',
#    'POL L OFC16-Ref',
#    'POL L SGC1-Ref',
#    'POL L SGC2-Ref',
#    'POL L SGC3-Ref',
#    'POL L SGC4-Ref',
#    'POL L SGC5-Ref',
#    'POL L SGC6-Ref',
#    'POL L SGC7-Ref',
#    'POL L SGC8-Ref',
#    'POL L SGC9-Ref',
#    'POL L SGC10-Ref',
#    'POL L SGC11-Ref',
#    'POL L SGC12-Ref',
#    'POL L SGC13-Ref',
#    'POL L SGC14-Ref',
#    'POL L SGC15-Ref',
#    'POL L SGC16-Ref',
#    'POL L H1-Ref',
#    'POL L H2-Ref',
#    'POL L H3-Ref',
#    'POL L H4-Ref',
#    'POL L H5-Ref',
#    'POL L H6-Ref',
#    'POL L H7-Ref',
#    'POL L H8-Ref',
#    'POL L H9-Ref',
#    'POL L H10-Ref',
#    'POL L H11-Ref',
#    'POL L H12-Ref',
#    'POL L H13-Ref',
#    'POL L H14-Ref',
#    'POL L H15-Ref',
#    'POL L H16-Ref',
#    'POL L A1-Ref',
#    'POL L A2-Ref',
#    'POL L A3-Ref',
#    'POL L A4-Ref',
#    'POL L A5-Ref',
#    'POL L A6-Ref',
#    'POL L A7-Ref',
#    'POL L A8-Ref',
#    'POL L A9-Ref',
#    'POL L A10-Ref',
#    'POL L A11-Ref',
#    'POL L A12-Ref',
#    'POL L A13-Ref',
#    'POL L A14-Ref',
#    'POL L A15-Ref',
#    'POL L A16-Ref',
#    'POL R VC1-Ref',
#    'POL R VC2-Ref',
#    'POL R VC3-Ref',
#    'POL R VC4-Ref',
#    'POL R VC5-Ref',
#    'POL R VC6-Ref',
#    'POL R VC7-Ref',
#    'POL R VC8-Ref',
#    'POL R VC9-Ref',
#    'POL R VC10-Ref',
#    'POL R VC11-Ref',
#    'POL R VC12-Ref',
#    'POL R VC13-Ref',
#    'POL R VC14-Ref',
#    'POL R VC15-Ref',
#    'POL R VC16-Ref',
#    'POL L VC1-Ref',
#    'POL L VC2-Ref',
#    'POL L VC3-Ref',
#    'POL L VC4-Ref',
#    'POL L VC5-Ref',
#    'POL L VC6-Ref',
#    'POL L VC7-Ref',
#    'POL L VC8-Ref',
#    'POL L VC9-Ref',
#    'POL L VC10-Ref',
#    'POL L VC11-Ref',
#    'POL L VC12-Ref',
#    'POL L VC13-Ref',
#    'POL L VC14-Ref',
#    'POL L VC15-Ref',
#    'POL L VC16-Ref',
#    'POL Fp1-Ref',
#    'POL F7-Ref',
#    'POL T7-Ref',
#    'POL P7-Ref',
#    'POL F3-Ref',
#    'POL C3-Ref',
#    'POL P3-Ref',
#    'POL O1-Ref',
#    'POL Fp2-Ref',
#    'POL F8-Ref',
#    'POL T8-Ref',
#    'POL P8-Ref',
#    'POL F4-Ref',
#    'POL C4-Ref',
#    'POL P4-Ref',
#    'POL O2-Ref',
#    'POL Fz-Ref',
#    'POL Cz-Ref',
#    'POL Pz-Ref',
#    'POL A1-Ref',
#    'POL A2-Ref',
#    'POL L EOG-Ref',
#    'POL R EOG-Ref',
#    'POL EMG1-Ref',
#    'POL EMG2-Ref',
#    'POL EKG1-Ref',
#    'POL EKG2-Ref']},
#  array([[ -732.6       ,  -732.6       ,  -732.6       , ...,
#           -732.6       ,  -732.6       ,  -732.6       ],
#         [ -732.6       ,  -732.6       ,  -732.6       , ...,
#           -732.6       ,  -732.6       ,  -732.6       ],
#         [-1098.9       , -1098.9       , -1098.9       , ...,
#          -1098.9       , -1098.9       , -1098.9       ],
#         ...,
#         [   42.57342184,    38.66717327,    31.63592584, ...,
#            525.38574502,   519.91699702,   503.12012818],
#         [   17.18280613,    13.66718242,     4.68281071, ...,
#            933.97934539,   922.65122454,   897.65123369],
#         [   66.01091325,    62.49528954,    55.07341726, ...,
#            787.88564889,   782.02627604,   761.71378347]]))
